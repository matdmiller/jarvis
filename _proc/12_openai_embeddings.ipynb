# %% [raw]
# ---
# description: Convert text to semantic embeddings with the OpenAI API
# output-file: openai_embeddings.html
# title: openai_embeddings
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/matdmiller/jarvis/blob/main/jarvis/to_be_allocated1.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()
